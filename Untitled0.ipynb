# %% [markdown]
# <a href="https://colab.research.google.com/github/leandroreyescalderon09-hash/tareas/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
frutas=["manzana","banana","naranja","uva"]

# %%
print(frutas)
# Out:
# ['manzana', 'banana', 'naranja', 'uva']

# %%
numeros=[4, 8, 15, 16, 23, 42]

# %%
print(numeros)
# Out:
# [4, 8, 15, 16, 23, 42]

# %%
print(numeros[0])
# Out:
# 4

# %%
print(numeros[-1])
# Out:
# 42

# %%
colores=["red", "blue", "green", "yellow"]

# %%
print(colores)
# Out:
# ['red', 'blue', 'green', 'yellow']

# %%
print(colores[1],colores[2])
# Out:
# blue green

# %%
ciudades=["bogota","medellin","cali","barranquilla","bucaramanga"]

# %%
print(ciudades)
# Out:
# ['bogota', 'medellin', 'cali', 'barranquilla', 'bucaramanga']

# %%
for i,ciudad in enumerate(ciudades):
    print(i,ciudad)
# Out:
# 0 bogota
# 1 medellin
# 2 cali
# 3 barranquilla
# 4 bucaramanga

# %%
animales=["perro","gato","conejo"]

# %%
print(animales)
# Out:
# ['perro', 'gato', 'conejo']

# %%
animales.append("hamster")
print(animales)
# Out:
# ['perro', 'gato', 'conejo', 'hamster']

# %%
animales.insert(1,"pajaro")
print(animales)
# Out:
# ['perro', 'pajaro', 'gato', 'conejo', 'hamster']

# %%
numeros=[10,20,30,40,50]
print(numeros)
# Out:
# [10, 20, 30, 40, 50]

# %%
numeros.remove(30)
print(numeros)
# Out:
# [10, 20, 40, 50]

# %%
letras=["a", "b", "c", "d", "e"]
print(letras)
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
letras.pop(-1)
print(letras)
# Out:
# ['a', 'b', 'c', 'd']

# %%
nombres=["Ana", "Luis", "Maria", "Pedro"]
print(nombres)
# Out:
# ['Ana', 'Luis', 'Maria', 'Pedro']

# %%
if "Maria" in nombres:  print(True)
else:
    print(False)
# Out:
# True

# %%
numbers = [5, 2, 9, 1, 7]
print(numbers)
# Out:
# [5, 2, 9, 1, 7]

# %%
numbers.sort()
print(numbers)
# Out:
# [1, 2, 5, 7, 9]

# %%
numbers.sort(reverse=True)
print(numbers)
# Out:
# [9, 7, 5, 2, 1]

# %%
numeros1 = [3, 6, 9, 12, 15]
print(numeros1)
# Out:
# [3, 6, 9, 12, 15]

# %%
nueva_lista=[ n * 2 for n in numeros1]
print(nueva_lista)
# Out:
# [6, 12, 18, 24, 30]

# %%
palabras = ["python", "list", "exercise", "practice"]
print(palabras)
# Out:
# ['python', 'list', 'exercise', 'practice']

# %%
for palabra in palabras:
    print(palabra)
# Out:
# python
# list
# exercise
# practice

# %%
grados = [80, 75, 90, 85, 95]
print(grados)
# Out:
# [80, 75, 90, 85, 95]

# %%
promedio = sum(grados) / len(grados)
print(promedio)
# Out:
# 85.0
