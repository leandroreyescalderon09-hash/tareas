# %% [markdown]
# <a href="https://colab.research.google.com/github/leandroreyescalderon09-hash/tareas/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
student = {"nombre": "Leandro","edad": 17,"grado": "1,semestre"}

print(student)
# Out:
# {'nombre': 'Leandro', 'edad': 17, 'grado': '1,semestre'}

# %%
car = {"brand": "Toyota", "model": "Corolla", "year": 2020}
print(car)
# Out:
# {'brand': 'Toyota', 'model': 'Corolla', 'year': 2020}

# %%
print(car['brand'])
# Out:
# Toyota

# %%
print(car.get("year"))
# Out:
# 2020

# %%
person = {"name": "Alice", "age": 25}
print(person)
# Out:
# {'name': 'Alice', 'age': 25}

# %%
person["city"]="Bogota"
print(person)
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Bogota'}

# %%
person["age"]=26
print(person)
# Out:
# {'name': 'Alice', 'age': 26, 'city': 'Bogota'}

# %%
del person["city"]
print(person)
# Out:
# {'name': 'Alice', 'age': 26}

# %%
fruits = {"apple": 3, "banana": 5, "orange": 2}
print(fruits)
# Out:
# {'apple': 3, 'banana': 5, 'orange': 2}

# %%
print(fruits.keys())
# Out:
# dict_keys(['apple', 'banana', 'orange'])

# %%
print(fruits.values())
# Out:
# dict_values([3, 5, 2])

# %%
for keys,values in fruits.items():
    print(keys,values)
# Out:
# apple 3
# banana 5
# orange 2

# %%
grades = {"Ana": 85, "Luis": 90, "Maria": 78}
print(grades)
# Out:
# {'Ana': 85, 'Luis': 90, 'Maria': 78}

# %%
print("Luis" in grades)
# Out:
# True

# %%
print("Pedro" in grades)
# Out:
# False

# %%
numbers = {"a": 10, "b": 20, "c": 30}
print(numbers)
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %%
print(sum(numbers.values()))
# Out:
# 60

# %%
inventory = {"pens": 10, "notebooks": 5, "erasers": 8}
print(inventory)
# Out:
# {'pens': 10, 'notebooks': 5, 'erasers': 8}

# %%
print(len(inventory))
# Out:
# 3

# %%
countries = {"Colombia": "Bogota", "France": "Paris", "Japan": "Tokyo"}
print (countries)
# Out:
# {'Colombia': 'Bogota', 'France': 'Paris', 'Japan': 'Tokyo'}

# %%
for country, capital in countries.items():
  print(country, capital)
# Out:
# Colombia Bogota
# France Paris
# Japan Tokyo

# %%
temperatures = {"Monday": 22, "Tuesday": 24, "Wednesday": 21, "Thursday": 23}
print(temperatures)
# Out:
# {'Monday': 22, 'Tuesday': 24, 'Wednesday': 21, 'Thursday': 23}

# %%
print(max(temperatures.values()))
# Out:
# 24
